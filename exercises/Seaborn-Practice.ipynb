# %%
import seaborn as sns
sns.set_theme(style="dark", palette="pastel")
penguins = sns.load_dataset("penguins")

# g = sns.catplot(
#     data=penguins, kind="violin",
#     x="species", y="body_mass_g", hue="sex", alpha=.6, height=6
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# sns.boxenplot(data = penguins, x = "species", y = "")

# sns.heatmap(data = penguins, x = "island", y = "species")

# sns.scatterplot(data=penguins, x="species", y="island", size = pd.penguins.count(penguins.species), legend=False)
islandpens = sns.histplot(data = penguins, y = "island", hue = "species", multiple="stack", 
            stat = "count", binwidth=.5)
